# %%
print("Aditya rao")
# Out:
# Aditya rao

# %%
#variable

num=10
print(num)
print(id(num))

num1=10
print(num1)
print(id(num1))

print(type(num))
print(type(num1))
# Out:
# 10
# 140736058078408
# 10
# 140736058078408
# <class 'int'>
# <class 'int'>
