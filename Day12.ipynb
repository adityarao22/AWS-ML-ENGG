# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
print(pd.read_csv("file1.csv"))
# Out:
#        name  roll no
# 0   dheeraj      123
# 1     kunal     1234
# 2  abhishek    12345
# 3   praveen    12356
# 4    anjali  1234567

# %%
a=pd.DataFrame()
print(a)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
