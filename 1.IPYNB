# %%
a="hello"
print(a)
print(id(a))
# Out:
# hello
# 2833595642720

# %%
#arithmetic operator 
#+,-.,*,/,//,%,**
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
#logical operator
#and,or,not
a=0
b=10
x=[]
print(not x)
print(not a)
print(not b)
# Out:
# True
# True
# False

# %%
num1={"name":"Aditya"}
num2=[20]
print(not num1 and num2)
# Out:
# False

# %%
num1={"name":"Aditya"}
num2= "[20]"
print(not num1 or not num2)
# Out:
# False
