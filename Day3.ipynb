# %%
#if

num1=10
if num1>2:
    print("num1 = ",num1)
print("if end")
# Out:
# num1 =  10
# if end

# %%
num1 = 20
num2 = 10
if num1<=num2:
    print("num1 is less than or equal to num2")
else:
    print("num1 is greater than num2")
# Out:
# num1 is greater than num2

# %%
num1=10
num2=20
num3=30
if num1>num2:
    print("if part run")
elif num1>num3:
    print("elif part run")
else:
    print("else part run")
# Out:
# else part run
